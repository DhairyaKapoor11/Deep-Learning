# %%
import cv2

# %%
img = cv2.imread('apple.jpg')

# %%
# Drawing a rectangle

# %%
cv2.rectangle(img, (50,50), (200,300), (123,200,111), 15)
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=526x612 at 0x7FC391DAE5C0>
