# %%
import cv2

# %%
faceCascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
Img = cv2.imread('Cricket.jpg')

# %%
gray = cv2.cvtColor(Img, cv2.COLOR_BGR2GRAY)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=1600x900 at 0x7FFBBDC617F0>

# %%
faces = faceCascade.detectMultiScale(gray, scaleFactor = 1.2, minNeighbors = 5, minSize = (20, 20) )

# %%
print(faces)
# Out:
# [[ 751  220  111  111]
#  [ 966  241  102  102]
#  [ 559  263   99   99]
#  [ 401  264  101  101]
#  [1262  272   92   92]
#  [1133  274   94   94]
#  [1398  285   92   92]
#  [ 245  293   87   87]
#  [  80  309   93   93]]

# %%
for (x, y, w, h) in faces:
  cv2.rectangle(Img, (x, y), (x + w, y + h), (255, 0, 0), 2)

# %%
cv2_imshow(Img)
cv2.imwrite('FaceDetected.jpg', Img)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x900 at 0x7FFBB3B0CB00>
# True
